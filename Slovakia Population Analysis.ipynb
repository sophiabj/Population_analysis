# %%
import geopandas as gpd 
import os 
import rasterio
import scipy.sparse as sparse 
import numpy as np
import pandas as pd


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# 2006 dataset has a shapefile and a csv file
#The coordinates will be extracted fom the shapefile while the population values will be obtained from the csv file

# %%
df = pd.read_csv('GEOSTAT_grid_EU_POP_2006_1K_V1_1_1.csv', sep=';')
df_2006 = df[['GRD_ID', 'POP_TOT']]

# %%
df_2006.head()
# Out:
#           GRD_ID  POP_TOT
# 0  1kmN5142E2862        2
# 1  1kmN5141E2862       13
# 2  1kmN5141E2864      211
# 3  1kmN5140E2862        1
# 4  1kmN5139E2876       33

# %%
# Read the points shapefile using GeoPandas 
stations_2006 = gpd.read_file(r'Grid_ETRS89_LAEA_1K_ref_GEOSTAT_2006.shp')

# %%
# Create a GeoDataFrame
gdf_2006 = gpd.GeoDataFrame(stations_2006, geometry='geometry', crs='EPSG:3035')

# Define the original coordinate system (UTM)
original_crs = {'init': 'epsg:3035'}  # Replace with the correct EPSG code for your data

# Transform the geometry to latitude and longitude
gdf_2006.to_crs(epsg=4326, inplace=True)  # 4326 is the EPSG code for WGS84 (latitude and longitude)

# Extract latitude and longitude from the transformed geometry
gdf_2006['latitude'] = gdf_2006['geometry'].centroid.y
gdf_2006['longitude'] = gdf_2006['geometry'].centroid.x
# Out:
# /var/folders/3x/53s4q5nj6516q9d1lrgjzpsr0000gn/T/ipykernel_20960/1812756185.py:11: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_2006['latitude'] = gdf_2006['geometry'].centroid.y
# /var/folders/3x/53s4q5nj6516q9d1lrgjzpsr0000gn/T/ipykernel_20960/1812756185.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_2006['longitude'] = gdf_2006['geometry'].centroid.x

# %%
gdf_2006 = gdf_2006[['GRD_INSPIR', 'latitude', 'longitude']]

# %%
gdf_2006.head()
# Out:
#       GRD_INSPIR   latitude  longitude
# 0  1kmN1760E2636  37.025516  -8.991978
# 1  1kmN1954E2636  38.723753  -9.483677
# 2  1kmN1960E2636  38.776153  -9.499447
# 3  1kmN1961E2636  38.784885  -9.502079
# 4  1kmN1760E2637  37.027749  -8.981059

# %% [markdown]
# The 2021 Population folder has a .gpkg file which contains coordinates and raster data

# %%
#Read the .gpkg file

stations_2021 = gpd.read_file(r'ESTAT_Census_2021_V1-0.gpkg')

# %%
# Create a GeoDataFrame FOR 2021
gdf_2021 = gpd.GeoDataFrame(stations_2021, geometry='geometry', crs='EPSG:3035')

# Define the original coordinate system (UTM)
original_crs = {'init': 'epsg:3035'}  # Replace with the correct EPSG code for your data

# Transform the geometry to latitude and longitude
gdf_2021.to_crs(epsg=4326, inplace=True)  # 4326 is the EPSG code for WGS84 (latitude and longitude)

# Extract latitude and longitude from the transformed geometry
gdf_2021['latitude'] = gdf_2021['geometry'].centroid.y
gdf_2021['longitude'] = gdf_2021['geometry'].centroid.x

# Display the resulting GeoDataFrame
#print(gdf[['GRD_ID', 'latitude', 'longitude']])
# Out:
# /var/folders/3x/53s4q5nj6516q9d1lrgjzpsr0000gn/T/ipykernel_20960/3435711038.py:11: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_2021['latitude'] = gdf_2021['geometry'].centroid.y
# /var/folders/3x/53s4q5nj6516q9d1lrgjzpsr0000gn/T/ipykernel_20960/3435711038.py:12: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_2021['longitude'] = gdf_2021['geometry'].centroid.x

# %%
gdf_2021.head()
# Out:
#                             GRD_ID  OBS_VALUE_T  \
# 0  CRS3035RES1000mN1000000E1964000          0.0
# 1  CRS3035RES1000mN1000000E1965000          0.0
# 2  CRS3035RES1000mN1000000E1966000        118.0
# 3  CRS3035RES1000mN1000000E1967000          4.0
# 4  CRS3035RES1000mN1000000E1968000          0.0
#
#                                             geometry   latitude  longitude
# 0  POLYGON ((-14.03656 28.68012, -14.02678 28.682...  28.685878 -14.032916
# 1  POLYGON ((-14.02678 28.68290, -14.01701 28.685...  28.688652 -14.023142
# 2  POLYGON ((-14.01701 28.68567, -14.00724 28.688...  28.691425 -14.013368
# 3  POLYGON ((-14.00724 28.68844, -13.99746 28.691...  28.694196 -14.003593
# 4  POLYGON ((-13.99746 28.69121, -13.98769 28.693...  28.696967 -13.993817

# %%
gdf_2021 = gdf_2021[['GRD_ID', 'OBS_VALUE_T', 'latitude', 'longitude']]

# %%
gdf_2021.head()
# Out:
#                             GRD_ID  OBS_VALUE_T   latitude  longitude
# 0  CRS3035RES1000mN1000000E1964000          0.0  28.685878 -14.032916
# 1  CRS3035RES1000mN1000000E1965000          0.0  28.688652 -14.023142
# 2  CRS3035RES1000mN1000000E1966000        118.0  28.691425 -14.013368
# 3  CRS3035RES1000mN1000000E1967000          4.0  28.694196 -14.003593
# 4  CRS3035RES1000mN1000000E1968000          0.0  28.696967 -13.993817

# %%
gdf_2021.dtypes
# Out:
# GRD_ID          object
# OBS_VALUE_T    float64
# latitude       float64
# longitude      float64
# dtype: object

# %%
def dms_to_decimal(degrees, minutes, seconds, direction):
    sign = 1 if direction in ["N", "E"] else -1
    decimal_degrees = degrees + minutes / 60 + seconds / 3600
    return sign * decimal_degrees

# %% [markdown]
# Geographic Bounding Box for Slovakia
#
# northernmost point: Oravská Polhora, 49°36′49.43′′N 19°28′2.52′′E
# southernmost point: Patince, 47°44′1.29′′N 18°17′20.93′′E
# westernmost point: Záhorská Ves, 48°22′50.24′′N 16°50′0.74′′E
# easternmost point: Nová Sedlica, 49°5′16.81′′N 22°33′56.7′′E

# %%
# Define the coordinates of the Slovakia bounding box

north_lat = dms_to_decimal(49, 36, 49.43, "N") # Oravská Polhora latitude
north_lon = dms_to_decimal(19, 28, 2.52, "E") # Oravská Polhora longitude
south_lat = dms_to_decimal(47, 44, 1.29, "N") # Patince latitude
south_lon = dms_to_decimal(18, 17, 20.93, "E") #Patince longitude
west_lat = dms_to_decimal(48, 22, 50.24, "N")# Záhorská Ves latitude
west_lon = dms_to_decimal(16, 50, 0.74, "E") # Záhorská Ves longitude
east_lat = dms_to_decimal(49, 5, 16.81, "E") # Nová Sedlica latitude
east_lon = dms_to_decimal(22, 33, 56.7, "E")   # Nová Sedlica longitude

# %%
print(north_lat)
print(north_lon)
print(south_lat)
print(south_lon)
print(west_lat)
print(west_lon)
print(east_lat)
print(east_lon)
# Out:
# 49.613730555555556
# 19.467366666666663
# 47.733691666666665
# 18.289147222222223
# 48.38062222222222
# 16.83353888888889
# 49.08800277777778
# 22.56575

# %%
from shapely.geometry import box  # Import box from Shapely

# Create a GeoDataFrame with the bounding box polygon
bbox = gpd.GeoDataFrame(
    geometry=[box(west_lon, south_lat, east_lon, north_lat)],
    crs="EPSG:4326"  # Coordinate Reference System: WGS84
)


# Filter the coordinates within the bounding box
slovakia_data = gpd.clip(stations_2006, bbox)

# %%
len(slovakia_data)
# Out:
# 29341

# %%
slovakia_data.head()
# Out:
#             GRD_INSPIR                                           geometry  \
# 1479147  1kmN2764E4889  POLYGON ((17.58342 47.73621, 17.59669 47.73529...
# 1478508  1kmN2764E4888  POLYGON ((17.57015 47.73713, 17.58342 47.73621...
# 1476595  1kmN2764E4885  POLYGON ((17.53035 47.73989, 17.54362 47.73897...
# 1475932  1kmN2764E4884  POLYGON ((17.51708 47.74080, 17.53035 47.73989...
# 1491907  1kmN2766E4908  POLYGON ((17.83818 47.73630, 17.85145 47.73535...
#
#           latitude  longitude
# 1479147  47.731280  17.589394
# 1478508  47.732202  17.576126
# 1476595  47.734956  17.536322
# 1475932  47.735871  17.523053
# 1491907  47.731351  17.844130

# %%
# Merge DataFrames based on columns 'latitude' and 'longitude'
merged_slovakia_df = pd.merge(slovakia_data, gdf_2021, on=['latitude', 'longitude'])

# %%
len(merged_slovakia_df)
# Out:
# 21383

# %%
merged_slovakia_df.head()
# Out:
#       GRD_INSPIR                                           geometry  \
# 0  1kmN2764E4889  POLYGON ((17.58342 47.73621, 17.59669 47.73529...
# 1  1kmN2764E4888  POLYGON ((17.57015 47.73713, 17.58342 47.73621...
# 2  1kmN2764E4885  POLYGON ((17.53035 47.73989, 17.54362 47.73897...
# 3  1kmN2764E4884  POLYGON ((17.51708 47.74080, 17.53035 47.73989...
# 4  1kmN2766E4908  POLYGON ((17.83818 47.73630, 17.85145 47.73535...
#
#     latitude  longitude                           GRD_ID  OBS_VALUE_T
# 0  47.731280  17.589394  CRS3035RES1000mN2764000E4889000        232.0
# 1  47.732202  17.576126  CRS3035RES1000mN2764000E4888000        266.0
# 2  47.734956  17.536322  CRS3035RES1000mN2764000E4885000          0.0
# 3  47.735871  17.523053  CRS3035RES1000mN2764000E4884000        550.0
# 4  47.731351  17.844130  CRS3035RES1000mN2766000E4908000        303.0

# %%
#Rename the GRID column in the csv to correspond for merging

df_2006 = df_2006.rename(columns= {'GRD_ID': 'GRD_INSPIR'})

# %%
df_2006.columns
# Out:
# Index(['GRD_INSPIR', 'POP_TOT'], dtype='object')

# %%
new_df = merged_slovakia_df[['GRD_INSPIR', 'GRD_ID', 'latitude', 'longitude', 'OBS_VALUE_T']]

# %%
#Finally merging slovakia region with the csv file that contains the population values for 2006.

final_df = pd.merge(new_df, df_2006, on=['GRD_INSPIR'])

# %%
len(final_df)
# Out:
# 21383

# %%
final_df.head(100)
# Out:
#        GRD_INSPIR                           GRD_ID   latitude  longitude  \
# 0   1kmN2764E4889  CRS3035RES1000mN2764000E4889000  47.731280  17.589394
# 1   1kmN2764E4888  CRS3035RES1000mN2764000E4888000  47.732202  17.576126
# 2   1kmN2764E4885  CRS3035RES1000mN2764000E4885000  47.734956  17.536322
# 3   1kmN2764E4884  CRS3035RES1000mN2764000E4884000  47.735871  17.523053
# 77  1kmN2784E5051  CRS3035RES1000mN2784000E5051000  47.739074  19.766458
# 78  1kmN2782E5032  CRS3035RES1000mN2782000E5032000  47.743491  19.511619
# 79  1kmN2782E5031  CRS3035RES1000mN2782000E5031000  47.744645  19.498380
# 80  1kmN2782E5030  CRS3035RES1000mN2782000E5030000  47.745798  19.485141
# 81  1kmN2782E5043  CRS3035RES1000mN2782000E5043000  47.730688  19.657206
# 82  1kmN2782E5039  CRS3035RES1000mN2782000E5039000  47.735366  19.604273
# 83  1kmN2784E5044  CRS3035RES1000mN2784000E5044000  47.747337  19.673819
# 84  1kmN2785E5044  CRS3035RES1000mN2785000E5044000  47.756248  19.675510
# 85  1kmN2785E5043  CRS3035RES1000mN2785000E5043000  47.757422  19.662272
# 86  1kmN2786E5045  CRS3035RES1000mN2786000E5045000  47.763983  19.690443
# 87  1kmN2778E5013  CRS3035RES1000mN2778000E5013000  47.729475  19.253522
# 88  1kmN2779E5018  CRS3035RES1000mN2779000E5018000  47.732753  19.321341
# 89  1kmN2779E5017  CRS3035RES1000mN2779000E5017000  47.733885  19.308102
# 90  1kmN2779E5016  CRS3035RES1000mN2779000E5016000  47.735014  19.294862
# 91  1kmN2779E5015  CRS3035RES1000mN2779000E5015000  47.736142  19.281622
# 92  1kmN2777E5001  CRS3035RES1000mN2777000E5001000  47.733924  19.093023
# 93  1kmN2777E5000  CRS3035RES1000mN2777000E5000000  47.735028  19.079779
# 94  1kmN2777E4998  CRS3035RES1000mN2777000E4998000  47.737230  19.053291
# 95  1kmN2778E5000  CRS3035RES1000mN2778000E5000000  47.743950  19.081367
# 96  1kmN2778E4999  CRS3035RES1000mN2778000E4999000  47.745052  19.068120
# 97  1kmN2779E5004  CRS3035RES1000mN2779000E5004000  47.748445  19.135944
# 98  1kmN2778E5012  CRS3035RES1000mN2778000E5012000  47.730598  19.240283
# 99  1kmN2778E5011  CRS3035RES1000mN2778000E5011000  47.731719  19.227042
#
#     OBS_VALUE_T  POP_TOT
# 0         232.0        1
# 1         266.0       24
# 2           0.0        1
# 3         550.0      514
# 4         303.0      462
# 5        1686.0     1520
# 6         651.0      640
# 7         327.0      295
# 8           0.0       29
# 9           0.0       61
# 10        121.0      234
# 11         90.0       63
# 12          0.0       34
# 13         88.0       61
# 14         33.0       46
# 15        171.0      266
# 16          3.0      119
# 17        112.0       81
# 18         68.0       50
# 19         35.0       34
# 20        669.0      613
# 21        155.0      158
# 22          0.0        9
# 23         57.0       32
# 24          0.0        1
# 25          0.0        5
# 26         36.0       39
# 27          0.0        1
# 28          9.0        3
# 29         30.0        7
# 30          0.0       13
# 31          0.0       21
# 32          0.0        9
# 33         54.0       31
# 34          0.0       15
# 35          4.0        3
# 36         67.0       49
# 37         97.0       53
# 38         39.0       23
# 39          0.0       15
# 40          0.0        4
# 41        160.0      176
# 42        593.0      681
# 43        279.0      357
# 44          0.0       13
# 45        622.0      616
# 46         13.0        6
# 47        731.0      619
# 48         37.0       13
# 49        293.0      114
# 50        716.0      585
# 51        843.0      788
# 52        230.0      122
# 53          3.0        1
# 54        317.0      754
# 55       2231.0     1615
# 56         38.0       34
# 57       1295.0     1777
# 58       1244.0      963
# 59        189.0        1
# 60          6.0       19
# 61        165.0      270
# 62       1356.0     1364
# 63          6.0       62
# 64         57.0       55
# 65        597.0      490
# 66        231.0      124
# 67          0.0       36
# 68        334.0      475
# 69        122.0       31
# 70        475.0      543
# 71       1875.0     1945
# 72        451.0      611
# 73        505.0      541
# 74       1119.0     1344
# 75         42.0       28
# 76         42.0       37
# 77        855.0      907
# 78          0.0       20
# 79        326.0      169
# 80        757.0      554
# 81          0.0       95
# 82        197.0      238
# 83        785.0     1017
# 84       1222.0     1412
# 85        146.0      132
# 86         21.0       61
# 87        854.0      813
# 88         53.0       53
# 89          0.0        6
# 90        155.0      199
# 91        228.0      247
# 92        136.0      719
# 93        326.0      365
# 94          0.0       47
# 95       1292.0      965
# 96        450.0       37
# 97          6.0       44
# 98        189.0      277
# 99          0.0        3

# %%
final_df = final_df.rename(columns= {'OBS_VALUE_T': '2021_POP', 'POP_TOT': "2006_POP"})

# %%
#Get the percentage increase in population between 2006 and 2021

final_df['Relative_increase'] = (final_df['2021_POP'] - final_df['2006_POP']) / final_df['2006_POP'] * 100

# %%
final_df.head()
# Out:
#       GRD_INSPIR                           GRD_ID   latitude  longitude  \
# 0  1kmN2764E4889  CRS3035RES1000mN2764000E4889000  47.731280  17.589394
# 1  1kmN2764E4888  CRS3035RES1000mN2764000E4888000  47.732202  17.576126
# 2  1kmN2764E4885  CRS3035RES1000mN2764000E4885000  47.734956  17.536322
# 3  1kmN2764E4884  CRS3035RES1000mN2764000E4884000  47.735871  17.523053
# 4  1kmN2766E4908  CRS3035RES1000mN2766000E4908000  47.731351  17.844130
#
#    2021_POP  2006_POP  Relative_increase
# 0     232.0         1       23100.000000
# 1     266.0        24        1008.333333
# 2       0.0         1        -100.000000
# 3     550.0       514           7.003891
# 4     303.0       462         -34.415584

# %%
# Identify Top 5 Grid Cells with Highest Relative Increase

top_5_cells = final_df.nlargest(5, 'Relative_increase')

# Save the top 5 cells data
top_5_cells.to_csv('slovakia_top_5_areas.csv', index=False)

# %%
top_5_cells
# Out:
#          GRD_INSPIR                           GRD_ID   latitude  longitude  \
# 2108  1kmN2815E4857  CRS3035RES1000mN2815000E4857000  48.216395  17.229316
# 489   1kmN2771E4931  CRS3035RES1000mN2771000E4931000  47.753690  18.156191
# 1141  1kmN2803E4859  CRS3035RES1000mN2803000E4859000  48.107256  17.240703
# 2117  1kmN2816E4857  CRS3035RES1000mN2816000E4857000  48.225343  17.230599
# 3236  1kmN2814E4865  CRS3035RES1000mN2814000E4865000  48.200358  17.335189
#
#       2021_POP  2006_POP  Relative_increase
# 2108    1059.0         3            35200.0
# 489      341.0         1            34000.0
# 1141     305.0         1            30400.0
# 2117    1212.0         4            30200.0
# 3236     466.0         2            23200.0

# %%
# Calculate Average and Median Population for Slovakia in 2021

average_population = final_df['2021_POP'].mean()
median_population = final_df['2021_POP'].median()

# Save the results
results = pd.DataFrame({'average_population': [average_population], 'median_population': [median_population]})
results.to_csv('slovakia_2021_population_stats.csv', index=False)

# %%
print(average_population)
print(median_population)
# Out:
# 311.72001122386945
# 99.0
